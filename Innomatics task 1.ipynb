# %% [markdown]
# ## 1) Here is a sample line of code that can be executed in Python:
#
# print("Hello, World!")

# %%
if __name__ == '__main__':
    print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## 2) Given an integer n , perform the following conditional actions:
#
# If n is odd, print Weird
# If n is even and in the inclusive range of 2 to 5, print Not Weird
# If n is even and in the inclusive range of 6 to 20, print Weird
# If n is even and greater than 20, print Not Weirdint Not Weird.

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    mod = n%2
    if mod == 1:
        print('Weird')
    elif 2 <= n <=5:
        print('Not Weird')
    elif 6 <= n <=20:
        print('Weird')
    elif n > 20:
        print('Not Weird')
# Out:
#  4
# Not Weird

# %% [markdown]
# ## 3) Add code to print three lines where:
#
# The first line contains the sum of the two numbers.
# The second line contains the difference of the two numbers (first − second).
# The third line contains the product of the two numbers.

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)
# Out:
#  2
#  3
# 5
# -1
# 6

# %% [markdown]
# ## 4) Add logic to print two lines.
# The first line should contain the result of integer division, a // b.
# The second line should contain the result of float division, a / b.

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(int(a // b))
    print(a/b)
# Out:
#  20
#  5
# 4
# 4.0

# %% [markdown]
# ## 5) n= input ,For all non-negative integers i < n, print i².

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(0,n):
        print(i*i)
# Out:
#  3
# 0
# 1
# 4

# %% [markdown]
# ## 6) Given a year, determine whether it is a leap year. If it is a leap year, return the Boolean True, otherwise return False.

# %%
def is_leap(year):
    leap = False
    
    # Write your logic here
    if year % 4==0:
        leap = True
        if year % 100 == 0:
            if year % 400 == 0:
                leap = True
            else:
                leap = False
    return leap

year = int(input())
is_leap(year)
# Out:
#  2004
# True

# %% [markdown]
# ## 7) n=input, Without using any string methods, try to print the following:
# Print the list of integers from 1 through n as a string, without spaces.

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(1,n+1):
      print(i,end='')
# Out:
#  5
# 12345
